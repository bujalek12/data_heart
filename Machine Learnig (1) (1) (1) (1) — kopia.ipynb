# %%
import pandas as pd

# %%
heart = pd.read_csv("D:\semestr 6\wstęp do uczenia maszynowego\machine learning\heartost.csv")
heart.head()
# Out:
#         Age  ChestPain    RestBP      Chol       Fbs   RestECG     MaxHR  \
# 0  0.947160  -1.796564  0.756274 -0.264463  2.390484  1.015005  0.017169
# 1  1.389703  -0.628412  1.608559  0.759159 -0.416945  1.015005 -1.818896
# 2  1.389703  -0.628412 -0.664201 -0.341717 -0.416945  1.015005 -0.900864
# 3 -1.929372   0.539740 -0.096011  0.063869 -0.416945 -0.995103  1.634655
# 4 -1.486829   1.707893 -0.096011 -0.824558 -0.416945  1.015005  0.978917
#
#      ExAng   Oldpeak     Slope        Ca      Thal  AHD  Sex
# 0 -0.69548  1.085542  2.270822 -0.709957 -2.277478    0    1
# 1  1.43311  0.396526  0.648041  2.500744 -0.565131    1    1
# 2  1.43311  1.343924  0.648041  1.430510  1.147216    1    1
# 3 -0.69548  2.119067  2.270822 -0.709957 -0.565131    0    1
# 4 -0.69548  0.310399 -0.974740 -0.709957 -0.565131    0    0

# %%
heart2 = pd.read_csv("D:\semestr 6\wstęp do uczenia maszynowego\machine learning\heartost2.csv")
heart2.head()
# Out:
#    ChestPain    RestBP      Chol       Fbs   RestECG     MaxHR    ExAng  \
# 0  -1.796564  0.756274 -0.264463  2.390484  1.015005  0.017169 -0.69548
# 1  -0.628412  1.608559  0.759159 -0.416945  1.015005 -1.818896  1.43311
# 2  -0.628412 -0.664201 -0.341717 -0.416945  1.015005 -0.900864  1.43311
# 3   0.539740 -0.096011  0.063869 -0.416945 -0.995103  1.634655 -0.69548
# 4   1.707893 -0.096011 -0.824558 -0.416945  1.015005  0.978917 -0.69548
#
#     Oldpeak     Slope        Ca      Thal  AHD  Sex  Age
# 0  1.085542  2.270822 -0.709957 -2.277478    0    1   63
# 1  0.396526  0.648041  2.500744 -0.565131    1    1   67
# 2  1.343924  0.648041  1.430510  1.147216    1    1   67
# 3  2.119067  2.270822 -0.709957 -0.565131    0    1   37
# 4  0.310399 -0.974740 -0.709957 -0.565131    0    0   41

# %%
heart.describe()

heart2.describe()
# Out:
#                 Age     ChestPain        RestBP          Chol           Fbs  \
# count  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02
# mean   5.334933e-16 -4.118451e-16  6.976451e-16  3.063190e-16  2.227774e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -2.814459e+00 -1.796564e+00 -2.141495e+00 -2.331021e+00 -4.169448e-01
# 25%   -7.123780e-01 -6.284120e-01 -6.642009e-01 -6.893626e-01 -4.169448e-01
# 50%    1.727088e-01 -6.284120e-01 -9.601098e-02 -1.099538e-01 -4.169448e-01
# 75%    7.258879e-01  5.397404e-01  4.721790e-01  5.467095e-01 -4.169448e-01
# max    2.496061e+00  1.707893e+00  3.881319e+00  6.128347e+00  2.390484e+00
#
#             RestECG         MaxHR         ExAng       Oldpeak         Slope  \
# count  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02
# mean  -1.278039e-15 -1.055261e-16 -1.110956e-15 -6.566071e-16  5.276307e-17
# ...

# %%
heart2.plot.scatter(x="Age", y="RestBP",figsize=(10.0, 7.5))
heart2.plot.hexbin(x="Age", y="RestBP",figsize=(8.5, 6.0), gridsize=(13, 7))
# Out:
# <Axes: xlabel='Age', ylabel='RestBP'>

# %%
heart2.plot.scatter(x="Age", y="Chol",figsize=(10.0, 7.5))
heart2.plot.hexbin(x="Age", y="Chol",figsize=(8.5, 6.0), gridsize=(13, 7))
# Out:
# <Axes: xlabel='Age', ylabel='Chol'>

# %%
heart2.plot.scatter(x="Age", y="MaxHR",figsize=(10.0, 7.5))
heart2.plot.hexbin(x="Age", y="MaxHR",figsize=(8.5, 6.0), gridsize=(13, 7))
# Out:
# <Axes: xlabel='Age', ylabel='MaxHR'>

# %%
heart2.plot.scatter(x="Age", y="Oldpeak",figsize=(10.0, 7.5))
heart2.plot.hexbin(x="Age", y="Oldpeak",figsize=(8.5, 6.0), gridsize=(13, 7))
# Out:
# <Axes: xlabel='Age', ylabel='Oldpeak'>

# %%
heart.corr()
# Out:
#                 Age  ChestPain    RestBP      Chol       Fbs   RestECG  \
# Age        1.000000  -0.173124  0.284946  0.208950  0.118530  0.148868
# ChestPain -0.173124   1.000000 -0.145149 -0.015387 -0.023976 -0.157005
# RestBP     0.284946  -0.145149  1.000000  0.130120  0.175340  0.146560
# Chol       0.208950  -0.015387  0.130120  1.000000  0.009841  0.171043
# Fbs        0.118530  -0.023976  0.175340  0.009841  1.000000  0.069564
# RestECG    0.148868  -0.157005  0.146560  0.171043  0.069564  1.000000
# MaxHR     -0.393806   0.276304 -0.045351 -0.003432 -0.007854 -0.083389
# ExAng      0.091661  -0.314993  0.064762  0.061310  0.025665  0.084867
# Oldpeak    0.203805  -0.334661  0.189171  0.046564  0.005747  0.114133
# Slope      0.161770  -0.250500  0.117382 -0.004062  0.059894  0.133946
# Ca         0.365323  -0.190960  0.097528  0.123726  0.140764  0.131749
# Thal       0.060915  -0.170854  0.057031  0.078484  0.002364 -0.017152
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
plt.style.use("seaborn")
 

 
# 3. Plot the heatmap
plt.figure(figsize=(10,10))
heat_map = sns.heatmap( heart.corr(), linewidth = 1 , annot = True)
plt.title( "HeatMap using Seaborn Method" )
plt.show()
# Out:
# C:\Users\macie\AppData\Local\Temp\ipykernel_32300\3931630385.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
pca = PCA(n_components=2)
data_2d = pca.fit_transform(heart.drop(columns="AHD"))
data_2d_df = pd.DataFrame(data_2d,columns=["pca_0", "pca_1"])
data_2d_df.sample(n=5)
# Out:
#         pca_0     pca_1
# 106 -0.033523 -0.748137
# 154  3.175608 -1.140164
# 138  0.314751 -3.202979
# 130 -0.311999 -0.216743
# 240 -2.864820 -0.818840

# %%
colors, mapping = pd.factorize(heart["AHD"])
colors, mapping
data_2d_df.plot.scatter(x="pca_0", y="pca_1",
c=heart["AHD"], cmap="tab20", colorbar=False,
figsize=(10.0, 7.5))
# Out:
# <Axes: xlabel='pca_0', ylabel='pca_1'>

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2)
heart_2d_tsne = tsne.fit_transform(
    heart.drop(columns="AHD")
)
heart_2d_tsne_df = pd.DataFrame(heart_2d_tsne, 
                          columns=["tsne_0", "tsne_1"])
heart_2d_tsne_df.sample(n=5)
# Out:
#         tsne_0     tsne_1
# 19    9.277834  13.967825
# 148  -5.600214  10.214936
# 23    6.574223  -1.762495
# 21  -17.261049  -7.078860
# 278  -0.136150   5.268424

# %%
heart_2d_tsne_df.plot.scatter(x="tsne_0", y="tsne_1", 
                             c=heart["AHD"], cmap="tab20", colorbar=False,
                             figsize=(10.0, 7.5))
# Out:
# <Axes: xlabel='tsne_0', ylabel='tsne_1'>

# %% [markdown]
# ##KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
X, y = heart.drop(columns="AHD"), heart["AHD"]

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
X_train, X_test = train_test_split(heart,
                                   test_size=0.2, 
                                   random_state=2020)

# %%
grid_cv = GridSearchCV(KNeighborsClassifier(), 
                       param_grid={
                           "n_neighbors": range(1, 100)
                       }, cv=5, scoring="f1", 
                       verbose=1, n_jobs=6)

# %%
grid_cv.fit(X_train.drop(columns="AHD"), 
            X_train["AHD"])
# Out:
# Fitting 5 folds for each of 99 candidates, totalling 495 fits
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=6,
#              param_grid={'n_neighbors': range(1, 100)}, scoring='f1',
#              verbose=1)

# %%
grid_cv.best_score_
# Out:
# 0.7941006607390488

# %%
knn = grid_cv.best_estimator_
knn
# Out:
# KNeighborsClassifier(n_neighbors=53)

# %%
from sklearn.metrics import f1_score

# %%
f1_score(X_test["AHD"],
         knn.predict(X_test.drop(columns="AHD")))
# Out:
# 0.7755102040816326

# %%
##LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate

# %%
X = heart.drop(columns="AHD")
y = heart["AHD"]

# %%
lr = LogisticRegression(penalty="none", 
                        max_iter=10000)
scores = cross_validate(
    lr, X, y, cv=10, return_train_score=True,
    scoring=("accuracy", "precision", "recall", "f1")
)
scores
# Out:
# c:\Users\macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# c:\Users\macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# c:\Users\macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# ...

# %%
from sklearn.feature_selection import RFECV

# %%
selector = RFECV(lr, step=1, min_features_to_select=1, 
                 cv=5, scoring="f1")
selector.fit(X, y)
# Out:
# c:\Users\macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# c:\Users\macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# c:\Users\macie\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(
# ...

# %%
selected_features_df = pd.DataFrame({
    "selected": selector.support_,
    "ranking": selector.ranking_
}, index=X.columns)
selected_features_df
# Out:
#            selected  ranking
# Age            True        1
# ChestPain      True        1
# RestBP         True        1
# Chol           True        1
# Fbs            True        1
# RestECG        True        1
# MaxHR          True        1
# ExAng          True        1
# Oldpeak        True        1
# Slope          True        1
# Ca             True        1
# Thal           True        1
# Sex            True        1

# %%
feature_names = selected_features_df[
    selected_features_df["selected"] == True
].index
feature_names
# Out:
# Index(['Age', 'ChestPain', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR',
#        'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'Sex'],
#       dtype='object')

# %%
heart[feature_names.tolist() + ["AHD"]]
# Out:
#           Age  ChestPain    RestBP      Chol       Fbs   RestECG     MaxHR  \
# 0    0.947160  -1.796564  0.756274 -0.264463  2.390484  1.015005  0.017169
# 1    1.389703  -0.628412  1.608559  0.759159 -0.416945  1.015005 -1.818896
# 2    1.389703  -0.628412 -0.664201 -0.341717 -0.416945  1.015005 -0.900864
# 3   -1.929372   0.539740 -0.096011  0.063869 -0.416945 -0.995103  1.634655
# 4   -1.486829   1.707893 -0.096011 -0.824558 -0.416945  1.015005  0.978917
# ..        ...        ...       ...       ...       ...       ...       ...
# 298 -1.044285  -1.796564 -1.232391  0.334260 -0.416945 -0.995103 -0.769716
# 299  1.500339  -0.628412  0.699455 -1.037008  2.390484 -0.995103 -0.376274
# 300  0.283345  -0.628412 -0.096011 -2.234453 -0.416945 -0.995103 -1.512885
# 301  0.283345   1.707893 -0.096011 -0.206522 -0.416945  1.015005  1.066349
# 302 -1.818736   0.539740  0.358541 -1.384653 -0.416945 -0.995103  1.022633
#
#        ExAng   Oldpeak     Slope        Ca      Thal  Sex  AHD
# ...
